# %% [markdown]
# <a href="https://colab.research.google.com/github/fairandcompetition/ml4ai/blob/main/9%EC%9B%94_20%EC%9D%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %% [markdown]
# cd는 리눅스 코드라 #으로 추가 필기하면 안된

# %% [markdown]
# Taske for today 1

# %%
import pandas as pd

df = pd.read_csv('data/earthquakes.csv')

# %%
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
# Try loc and iloc function to select 3:10 items for mag,  magType, and type variables.
df.loc[3:10,['mag', 'magType', 'type']]
# Out:
#      mag magType        type
# 3   0.44      ml  earthquake
# 4   2.16      md  earthquake
# 5   2.61      md  earthquake
# 6   1.70      ml  earthquake
# 7   1.13      md  earthquake
# 8   0.92      md  earthquake
# 9   4.70      mb  earthquake
# 10  0.50      ml  earthquake

# %%
# Try loc and iloc function to select 3:10 items for mag,  magType, and type variables.
df.iloc[3:10, [8, 9, 22]]
# Out:
#     mag magType                                              types
# 3  0.44      ml         ,geoserve,nearby-cities,origin,phase-data,
# 4  2.16      md  ,geoserve,nearby-cities,origin,phase-data,scit...
# 5  2.61      md                       ,geoserve,origin,phase-data,
# 6  1.70      ml                                  ,geoserve,origin,
# 7  1.13      md  ,geoserve,nearby-cities,origin,phase-data,scit...
# 8  0.92      md  ,geoserve,nearby-cities,origin,phase-data,scit...
# 9  4.70      mb                       ,geoserve,origin,phase-data,

# %%
# Try to find items of location Arizona
df.loc[df.place.str.contains('Arizona')].filter(['mag', 'magType', 'type'])
# Out:
#        mag magType        type
# 1062  1.23      ml  earthquake
# 3965  0.94      md  earthquake

# %%
# Try to find 10 largest items of mag variable
df.loc[df['mag'].nlargest(10).index, ['mag', 'magType', 'type']]
# Out:
#       mag magType        type
# 5263  7.5     mww  earthquake
# 837   7.0     mww  earthquake
# 118   6.7     mww  earthquake
# 4363  6.7     mww  earthquake
# 799   6.5     mww  earthquake
# 816   6.2     mww  earthquake
# 838   6.1      mb  earthquake
# 5323  6.1     mww  earthquake
# 862   6.0     mww  earthquake
# 1267  6.0     mww  earthquake

# %% [markdown]
# Tasks for today 2

# %%
# Try to delete alert variable

del df['alert']
df.columns
# Out:
# Index(['cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag', 'magType',
#        'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time',
#        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
# Try to pop mag and magType variables one at a time  with name mag, and magType. (use .pop function)

mag = df.pop('mag')
magType = df.pop('magType')
df.columns
# Out:
# Index(['cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mmi', 'net',
#        'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time', 'title',
#        'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
# Concatenate mag and magType variables and define a  new DataFrame using .concat function


new_df = pd.concat([mag, magType], axis=1)
new_df
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]
